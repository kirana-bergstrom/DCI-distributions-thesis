# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import seaborn as sns

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import matplotlib.patches as patches

from scipy.stats import gaussian_kde as GKDE
from scipy.stats import multivariate_normal
from scipy.stats import norm
import scipy.integrate as integrate
from scipy.stats import multivariate_normal as mvn

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import src.weightedEDFs as wEDFs
import src.distributionsDCI as distDCI
import src.utils as utils

import matplotlib as mpl

# %%
plot_directory = './plots'

if not os.path.exists(plot_directory):
    os.makedirs(plot_directory)

mpl.rcParams['lines.linewidth'] = 4
plt.rc('font', size=14)
plt.rc('axes', titlesize=16)
plt.rc('axes', labelsize=16)
mpl.rcParams['lines.markersize'] = 5
mpl.rcParams['figure.figsize'] = (5.5, 4)
mpl.rcParams['lines.linewidth'] = 2.5

CB_color_cycle = ('#377eb8', '#ff7f00', '#4daf4a',
                  '#f781bf', '#a65628', '#984ea3',
                  '#999999', '#e41a1c', '#dede00')
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=CB_color_cycle) 
plt.rcParams['image.cmap'] = 'viridis'

# %% [markdown]
# ## Problem setup

# %%
np.random.seed(28)
random.seed(41)

# %%
l = 2.
kappa = 1.

# %%
N = 100  # Specify the truncation
ts = [1e-4, 1e-2, 1e-1, 0.4, 0.8]
x = np.linspace(0, l, 2*N)

# %%
def u_k(k, x, t, l, kappa):
    
    return (2 * l**2 * (-1)**(k+1) / (np.pi * k)
            * np.sin(k * np.pi * x / l)
            * np.exp(-kappa * (k * np.pi)**2 * t) / l**2)

def u(N, x, t, l, kappa):
    
    u_N = 0 * x
    for k in range(1, N):
        u_N += u_k(k, x, t, l, kappa)

    return u_N

# %%
for t in ts:

    u_N = u(N, x, t, l, kappa)
    plt.plot(x, u_N, label='t = ' + str(t));

plt.legend(loc='upper left', shadow=True)
plt.xlabel(r'$x$')
plt.ylabel(r'$u$')

plt.tight_layout()
plt.savefig(f'{plot_directory}/heat_eq_sol.png', bbox_inches='tight')

# %%
ts = [.01, 0.1]
sensor_loc = [1.2, 1.0]

# %% [markdown]
# ## Setup the standard DCI problem

# %%
n_init_samples = 5000

delta_l = 0.1
delta_kappa = 0.5

init_samples = np.random.uniform(0, 1, (n_init_samples,2))
init_samples[:,0] = init_samples[:,0] * delta_l + l - delta_l / 2
init_samples[:,1] = init_samples[:,1] * delta_kappa + kappa - delta_kappa / 2

# %%
X = np.linspace(l - delta_l / 2, delta_l + l - delta_l / 2, 100)
Y = np.linspace(kappa - delta_kappa / 2, delta_kappa + kappa - delta_kappa / 2, 100)

XX, YY = np.meshgrid(X, Y)
ZZ = np.zeros(np.shape(XX))

for count, x in enumerate(X):
    ZZ[count,:] = u(N, sensor_loc[0], ts[0], XX[count,:], YY[count,:])

# %%
plt.contourf(XX, YY, ZZ, levels=9);
ax = plt.gca()
ax.set_aspect(0.18)

plt.ylabel(r'$\kappa$');
plt.xlabel(r'$\ell$');
plt.xticks(ticks=np.linspace(np.min(XX), np.max(XX), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(XX), np.max(XX), 6)])
plt.yticks(ticks=np.linspace(np.min(YY), np.max(YY), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(YY), np.max(YY), 6)])

cbar = plt.colorbar()
cbar.set_ticks(np.linspace(np.min(ZZ), np.max(ZZ), 7))
cbar.set_ticklabels(["{:.4f}".format(x) for x in np.linspace(np.min(ZZ),
                                                             np.max(ZZ), 7)])

plt.tight_layout()
plt.savefig(f'{plot_directory}/contours.png', bbox_inches='tight')

# %%
plt.scatter(init_samples[:,0], init_samples[:,1], alpha=0.2, color='k')
ax = plt.gca()
ax.set_aspect(0.18)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\kappa$')
plt.xticks(ticks=np.linspace(np.min(XX), np.max(XX), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(XX), np.max(XX), 6)])
plt.yticks(ticks=np.linspace(np.min(YY), np.max(YY), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(YY), np.max(YY), 6)])

plt.tight_layout()
plt.savefig(f'{plot_directory}/heat_eq_init_samples.png', bbox_inches='tight')

# %%
pred_samples = np.zeros((n_init_samples, len(ts)))
for count, t in enumerate(ts):
    pred_samples[:, count] = u(N, sensor_loc[count], t, init_samples[:,0], init_samples[:,1])
    
pred_KDE = GKDE(pred_samples.T)

# %%
obs_dist = mvn([0.595, 0.25],[[0.000001, 0.0],[0.0, 0.0001]])

n_obs_samples = 8000
obs_samples = obs_dist.rvs(n_obs_samples)

obs_KDE = GKDE(obs_samples.T)

# %%
plt.hist(pred_samples[:,0], alpha=0.5,
         label=r'Predicted histogram in $\mathcal{I}_1$', bins=50, density=True)
plt.hist(obs_samples[:,0], alpha=0.5,
         label=r'Observed marginal histogram in $\mathcal{I}_1$', bins=30, density=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), shadow=True)
plt.tight_layout()
plt.savefig(f'{plot_directory}/decomposition_heat_dspace1.png', bbox_inches='tight')

# %%
plt.hist(pred_samples[:,1], alpha=0.5,
         label=r'Predicted histogram in $\mathcal{I}_2$', bins=50, density=True)
plt.hist(obs_samples[:,1], alpha=0.5,
         label=r'Observed marginal histogram in $\mathcal{I}_2$', bins=30, density=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), shadow=True)
plt.tight_layout()
plt.savefig(f'{plot_directory}/decomposition_heat_dspace2.png', bbox_inches='tight')

# %%
plt.scatter(pred_samples[:,0], pred_samples[:,1], alpha=0.5, label='Predicted samples')
plt.scatter(obs_samples[:,0], obs_samples[:,1], alpha=0.5, label='Observed samples')
plt.legend(shadow=True)
plt.tight_layout()
plt.savefig(f'{plot_directory}/decomposition_heat_dspace.png', bbox_inches='tight')

# %% [markdown]
# ## Density-based solution

# %%
r = obs_KDE(pred_samples.T) / pred_KDE(pred_samples.T)
rn_w = r / n_init_samples
print(f'E(r) = {np.mean(r)}')
# Out:
# E(r) = 1.1087371388149474

# %%
update_inds = utils.rejection_sampling(r)

update_samples = init_samples[update_inds]

pf_samples = pred_samples[update_inds]

pf_KDE = GKDE(pf_samples.T)

# %%
ax = plt.gca()
ax.set_aspect(0.18)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\kappa$')
plt.xticks(ticks=np.linspace(np.min(XX), np.max(XX), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(XX), np.max(XX), 6)])
plt.yticks(ticks=np.linspace(np.min(YY), np.max(YY), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(YY), np.max(YY), 6)])
plt.scatter(update_samples[:,0], update_samples[:,1])
plt.scatter([np.min(XX), np.min(XX), np.max(XX), np.max(XX)],
            [np.min(YY), np.max(YY), np.min(YY), np.max(YY)],
            color='w')
plt.tight_layout()
plt.savefig(f'{plot_directory}/decomposition_heat_rejection.png', bbox_inches='tight')

# %%
ax = plt.gca()
ax.set_aspect(0.18)

plt.scatter(init_samples[:,0], init_samples[:,1], c=r/n_init_samples)

plt.xlim(1.945, 2.055)
plt.ylim(0.725, 1.275)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\kappa$')
plt.xticks(ticks=np.linspace(np.min(XX), np.max(XX), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(XX), np.max(XX), 6)])
plt.yticks(ticks=np.linspace(np.min(YY), np.max(YY), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(YY), np.max(YY), 6)])

cbar = plt.colorbar()
cbar.set_ticks(np.linspace(np.min(r/n_init_samples), np.max(r/n_init_samples), 7))
cbar.set_ticklabels(["{:.4f}".format(x) for x in np.linspace(np.min(r/n_init_samples),
                                                             np.max(r/n_init_samples), 7)])

plt.tight_layout()
plt.savefig(f'{plot_directory}/decomposition_heat_density.png', bbox_inches='tight')

# %% [markdown]
# ## Binning methods

# %%
n_bins = 64

# %% [markdown]
# ### Regular partitioning

# %%
rpartitioned_w, bins, centers, w_center = distDCI.computePartitionedWeights_regulargrid_IID(init_samples,
                                                                        pred_samples,
                                                                        sample_set_2=np.reshape(obs_samples, (len(obs_samples),2)),
                                                                        n_bins=n_bins)

# %%
print(np.sum(rpartitioned_w)/35)
# Out:
# 0.023410087368597458

# %%
plt.scatter(init_samples[:,0], init_samples[:,1], c=rpartitioned_w)

plt.xlabel(r'$\ell$')
plt.ylabel(r'$\kappa$')
plt.xticks(ticks=np.linspace(np.min(XX), np.max(XX), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(XX), np.max(XX), 6)])
plt.yticks(ticks=np.linspace(np.min(YY), np.max(YY), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(YY), np.max(YY), 6)])

cbar = plt.colorbar()
cbar.set_ticks(np.linspace(np.min(rpartitioned_w), np.max(rpartitioned_w), 7))
cbar.set_ticklabels(["{:.4f}".format(x) for x in np.linspace(np.min(rpartitioned_w),
                                                             np.max(rpartitioned_w), 7)])

plt.tight_layout()
plt.savefig(f'{plot_directory}/decomposition_heat_rbinning.png', bbox_inches='tight')

# %%
for i in range(n_bins*n_bins):
    plt.scatter(init_samples[(bins==i),0],init_samples[(bins==i),1])

plt.xlabel(r'$\ell$')
plt.ylabel(r'$\kappa$')
plt.xticks(ticks=np.linspace(np.min(XX), np.max(XX), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(XX), np.max(XX), 6)])
plt.yticks(ticks=np.linspace(np.min(YY), np.max(YY), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(YY), np.max(YY), 6)])

plt.tight_layout()
plt.savefig(f'{plot_directory}/decomposition_heat_rcells.png', bbox_inches='tight')

# %% [markdown]
# ### K-means partitioning

# %%
n_clusters = 800
kpartitioned_w, clusters, centers, w_center = distDCI.computePartitionedWeights_kMeans_IID(init_samples,
                                                                        pred_samples,
                                                                        sample_set_2=np.reshape(obs_samples, (len(obs_samples),2)),
                                                                        n_clusters=n_clusters)

# %%
for i in range(n_clusters):
    plt.scatter(init_samples[(clusters==i),0], init_samples[(clusters==i),1])

plt.xlabel(r'$\ell$')
plt.ylabel(r'$\kappa$')

plt.xticks(ticks=np.linspace(np.min(XX), np.max(XX), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(XX), np.max(XX), 6)])
plt.yticks(ticks=np.linspace(np.min(YY), np.max(YY), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(YY), np.max(YY), 6)])

plt.tight_layout()
plt.savefig(f'{plot_directory}/decomposition_heat_kcells.png', bbox_inches='tight')

# %%
plt.scatter(init_samples[:,0], init_samples[:,1], c=kpartitioned_w)

plt.xlabel(r'$\ell$')
plt.ylabel(r'$\kappa$')
plt.xticks(ticks=np.linspace(np.min(XX), np.max(XX), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(XX), np.max(XX), 6)])
plt.yticks(ticks=np.linspace(np.min(YY), np.max(YY), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(YY), np.max(YY), 6)])

cbar = plt.colorbar()
cbar.set_ticks(np.linspace(np.min(kpartitioned_w), np.max(kpartitioned_w), 7))
cbar.set_ticklabels(["{:.4f}".format(x) for x in np.linspace(np.min(kpartitioned_w),
                                                             np.max(kpartitioned_w), 7)])

plt.tight_layout()
plt.savefig(f'{plot_directory}/decomposition_heat_kbinning.png', bbox_inches='tight')

# %%
w, ps = distDCI.computePartitionedWeights_kMeans_decomposition(init_samples, pred_samples,
                                                               sample_set_2=obs_samples, n_clusters=32)

# %%
plt.scatter(init_samples[:,0], init_samples[:,1], c=ps[0])

plt.xlabel(r'$\ell$')
plt.ylabel(r'$\kappa$')
plt.xticks(ticks=np.linspace(np.min(XX), np.max(XX), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(XX), np.max(XX), 6)])
plt.yticks(ticks=np.linspace(np.min(YY), np.max(YY), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(YY), np.max(YY), 6)])

cbar = plt.colorbar()
cbar.set_ticks(np.linspace(np.min(ps[0]), np.max(ps[0]), 7))
cbar.set_ticklabels(["{:.4f}".format(x) for x in np.linspace(np.min(ps[0]),
                                                             np.max(ps[0]), 7)])

plt.tight_layout()
plt.savefig(f'{plot_directory}/decomposition_heat_kiter_0.png', bbox_inches='tight')

# %%
plt.scatter(init_samples[:,0], init_samples[:,1], c=ps[1])

plt.xlabel(r'$\ell$')
plt.ylabel(r'$\kappa$')
plt.xticks(ticks=np.linspace(np.min(XX), np.max(XX), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(XX), np.max(XX), 6)])
plt.yticks(ticks=np.linspace(np.min(YY), np.max(YY), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(YY), np.max(YY), 6)])

cbar = plt.colorbar()
cbar.set_ticks(np.linspace(np.min(ps[1]), np.max(ps[1]), 7))
cbar.set_ticklabels(["{:.4f}".format(x) for x in np.linspace(np.min(ps[1]),
                                                             np.max(ps[1]), 7)])

plt.tight_layout()
plt.savefig(f'{plot_directory}/decomposition_heat_kiter_1.png', bbox_inches='tight')

# %%
plt.scatter(init_samples[:,0], init_samples[:,1], c=w)

plt.xlabel(r'$\ell$')
plt.ylabel(r'$\kappa$')
plt.xticks(ticks=np.linspace(np.min(XX), np.max(XX), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(XX), np.max(XX), 6)])
plt.yticks(ticks=np.linspace(np.min(YY), np.max(YY), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(YY), np.max(YY), 6)])

cbar = plt.colorbar()
cbar.set_ticks(np.linspace(np.min(w), np.max(w), 7))
cbar.set_ticklabels(["{:.4f}".format(x) for x in np.linspace(np.min(w),
                                                             np.max(w), 7)])

plt.tight_layout()
plt.savefig(f'{plot_directory}/decomposition_heat_kiter.png', bbox_inches='tight')

# %%
w = binning.computePartitionedWeights_regulargrid_decomposition(init_samples, pred_samples,
                                                       sample_set_2=obs_samples, n_clusters=25)

# %%
plt.scatter(init_samples[:,0], init_samples[:,1], c=w)

plt.xlabel(r'$\ell$')
plt.ylabel(r'$\kappa$')
plt.xticks(ticks=np.linspace(np.min(XX), np.max(XX), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(XX), np.max(XX), 6)])
plt.yticks(ticks=np.linspace(np.min(YY), np.max(YY), 6),
           labels=["{:.2f}".format(x) for x in np.linspace(np.min(YY), np.max(YY), 6)])

cbar = plt.colorbar()
cbar.set_ticks(np.linspace(np.min(w), np.max(w), 7))
cbar.set_ticklabels(["{:.4f}".format(x) for x in np.linspace(np.min(w),
                                                             np.max(w), 7)])

plt.tight_layout()
plt.savefig(f'{plot_directory}/decomposition_heat_riter.png', bbox_inches='tight')
